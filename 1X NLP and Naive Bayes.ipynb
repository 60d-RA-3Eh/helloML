# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import pandas as pd

# %%
# https://raw.githubusercontent.com/quankiquanki/skytrax-reviews-dataset/master/data/seat.csv
df = pd.read_csv('seat.csv')
df.head()
# Out:
#                 airline_name                                     link  \
# 0            aegean-airlines            /seat-reviews/aegean-airlines
# 1            aegean-airlines            /seat-reviews/aegean-airlines
# 2                 aer-lingus                 /seat-reviews/aer-lingus
# 3                 aer-lingus                 /seat-reviews/aer-lingus
# 4  aeroflot-russian-airlines  /seat-reviews/aeroflot-russian-airlines
#
#                                        title                    author  \
# 0            Aegean Airlines customer review               Jay Simpson
# 1            Aegean Airlines customer review              Paul Staples
# 2                 Aer Lingus customer review                 L Pulliam
# 3                 Aer Lingus customer review                   D Brose
# 4  Aeroflot Russian Airlines customer review  Konstantinos Grimpilakos
#
#    author_country        date  \
# 0  United Kingdom  2015-07-20
# 1  United Kingdom  2013-01-21
# 2   United States  2015-07-07
# 3   United States  2010-10-22
# 4          Greece  2015-08-02
#
#                                              content        aircraft  \
# 0  LHR to Larnaca return. Plane was clean and in ...        A320-200
# 1  For a short haul airline the seats are very go...     AIRBUS A320
# 2  The seats are a bit tight but bearable. If you...            A330
# 3  Appeared new. Good PTV entertainment. Seats ha...     Airbus A330
# 4  Boeing 737-800 seats from Athens to Moscow are...  Boeing 737-800
#
#   seat_layout  date_flown  ...  type_traveller overall_rating  \
# 0         3x3  19-07-2015  ...    Solo Leisure           10.0
# 1         3x3         NaN  ...             NaN            9.0
# 2       2x4x2  06-07-2015  ...  Couple Leisure            6.0
# 3       2x4x2         NaN  ...             NaN            5.0
# 4         3x3  01-07-2015  ...        Business            1.0
#
#    seat_legroom_rating  seat_recline_rating  seat_width_rating  \
# 0                    4                    4                  4
# 1                    4                    4                  4
# 2                    3                    3                  3
# 3                    2                    3                  3
# 4                    1                    1                  1
#
#    aisle_space_rating  viewing_tv_rating  power_supply_rating  \
# 0                   5                4.0                  NaN
# 1                   4                4.0                  NaN
# 2                   3                3.0                  3.0
# 3                   3                4.0                  NaN
# 4                   2                1.0                  5.0
#
#    seat_storage_rating  recommended
# 0                  4.0            1
# 1                  NaN            1
# 2                  3.0            1
# 3                  NaN            0
# 4                  1.0            1
#
# [5 rows x 21 columns]

# %%
df.rename(columns = {'content':'review'},inplace =True)

# %%
X_reviews = np.array(df['review'].values,dtype='object')
y = df['recommended']

# %%
y.value_counts()
# Out:
# 0    800
# 1    458
# Name: recommended, dtype: int64

# %% [markdown]
# ***
# # Text Pre-processing

# %% [markdown]
# <br>
#
# ### # Noice Removal
#
# * remove non-printable char (non-ascii and unicode char)

# %%
# All non-printable char are converted to nomal encoding thanks to read_csv of pandas lib

# %% [markdown]
# ### # Noice Removal
#
# * replace contractions

# %%
con_df = pd.read_csv('contractions.csv')
con_df.head()
# Out:
#   Contraction      Meaning
# 0       ain't       am not
# 1      aren't      are not
# 2       can't       cannot
# 3    can't've  cannot have
# 4      'cause      because

# %%
con_dict = {}
for _idx,Contraction,Meaning in con_df.itertuples():
    con_dict[Contraction] = Meaning

# %%
import re

# %%
print('(%s)' % '|'.join(con_dict.keys()))
# Out:
# (ain't|aren't|can't|can't've|'cause|could've|couldn't|couldn't've|didn't|doesn't|don't|hadn't|hadn't've|hasn't|haven't|he'd|he'd've|he'll|he'll've|he's|how'd|how'd'y|how'll|how's|i'd|i'd've|i'll|i'll've|i'm|i've|isn't|it'd|it'd've|it'll|it'll've|it's|let's|ma'am|mayn't|might've|mightn't|mightn't've|must've|mustn't|mustn't've|needn't|needn't've|o'clock|oughtn't|oughtn't've|shan't|sha'n't|shan't've|she'd|she'd've|she'll|she'll've|she's|should've|shouldn't|shouldn't've|so've|so's|that'd|that'd've|that's|there'd|there'd've|there's|they'd|they'd've|they'll|they'll've|they're|they've|to've|wasn't|we'd|we'd've|we'll|we'll've|we're|we've|weren't|what'll|what'll've|what're|what's|what've|when's|when've|where'd|where's|where've|who'll|who'll've|who's|who've|why's|why've|will've|won't|won't've|would've|wouldn't|wouldn't've|y'all|y'alls|y'all'd|y'all'd've|y'all're|y'all've|you'd|you'd've|you'll|you'll've|you're|you've)

# %%
# https://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
con_re = re.compile('(%s)' % '|'.join(con_dict.keys()))

def expandContractions(text, con_re=con_re):
    def replace(match):
        return con_dict[match.group()]
    return con_re.sub(replace, text.lower())

# %%
for idx in range(0,X_reviews.size):
    X_reviews[idx] = expandContractions(X_reviews[idx])

# %% [markdown]
# <br>
#
# ### # Tokenization
# * sent_tokenize

# %%
from nltk.tokenize import sent_tokenize

# %%
for idx in range(0,X_reviews.size):
    X_reviews[idx] = np.array(sent_tokenize(X_reviews[idx]),dtype='object')

# %% [markdown]
# <br>
#
# ### # Noice Removal
#
# * remove punctuations

# %%
import string

# %%
blank = str.maketrans('','',string.punctuation)

for idx in range(0,X_reviews.size):
    for jdx in range (0,X_reviews[idx].size):
        X_reviews[idx][jdx] = X_reviews[idx][jdx].translate(blank)

# %% [markdown]
# <br>
#
# ### # Tokenization
# * word_tokenize

# %%
from nltk.tokenize import word_tokenize

# %%
for idx in range(0,X_reviews.size):
    for jdx in range (0,X_reviews[idx].size):
        X_reviews[idx][jdx] = np.array(word_tokenize(X_reviews[idx][jdx]),dtype='object')

# %% [markdown]
# <br>
#
# ### # Noice Removal
#
# * remove stopwords

# %%
from nltk.corpus import stopwords

# %%
sw_ = stopwords.words('english')

for idx in range(0,X_reviews.size):
    for jdx in range (0,X_reviews[idx].size):
        sw_idxs = []
        for kdx in range (0,X_reviews[idx][jdx].size):
            if X_reviews[idx][jdx][kdx] in sw_:
                sw_idxs.append(kdx)
        X_reviews[idx][jdx] = np.delete(X_reviews[idx][jdx], sw_idxs)

# %% [markdown]
# <br>
#
# ***
# ## Updating dataFrame
# <br>

# %%
content =[]

for idx in range (0,X_reviews.size):
    content.append(' '.join([' '.join(sentence) for sentence in X_reviews[idx]]))
    
df['review'] = content

# %%
df[['review']].head()
# Out:
#                                               review
# 0  lhr larnaca return plane clean good condition ...
# 1  short haul airline seats good find seats comfo...
# 2  seats bit tight bearable courteous others cour...
# 3  appeared new good ptv entertainment seats tigh...
# 4  boeing 737800 seats athens moscow small table ...

# %% [markdown]
# ***
#
#
# <center><i><h1> Unsupervised </h1></i></center>
#
#
#
# <br>
# <br>
# <br>
#
# # Feature Extraction
# ### # Part-of-Speech Tagging
# * Each word in bag of word is assigned to respective POS.
# * Used to identify verb, adjective in case of _"sentiment mining"_ .

# %%
from nltk import pos_tag

# %%
pos_tag_list = []

for review in X_reviews:
    rev_list = [pos_tag(sentence) for sentence in review]
    pos_tag_list.append(rev_list)

# %%
print(pos_tag_list)
# Out:
# [[[('lhr', 'JJ'), ('larnaca', 'NN'), ('return', 'NN')], [('plane', 'NN'), ('clean', 'JJ'), ('good', 'JJ'), ('condition', 'NN')], [('drinks', 'NNS'), ('served', 'VBD'), ('throughout', 'IN'), ('flights', 'NNS')], [('food', 'NN'), ('good', 'NN')], [('would', 'MD'), ('definitely', 'RB'), ('hesitate', 'VB'), ('use', 'NN'), ('airline', 'NN'), ('european', 'JJ'), ('trips', 'NNS')]], [[('short', 'JJ'), ('haul', 'NN'), ('airline', 'NN'), ('seats', 'NNS'), ('good', 'JJ')], [('find', 'VB'), ('seats', 'NNS'), ('comfortable', 'JJ'), ('plenty', 'JJ'), ('leg', 'NN'), ('room', 'NN')]], [[('seats', 'NNS'), ('bit', 'VBP'), ('tight', 'JJ'), ('bearable', 'NN')], [('courteous', 'JJ'), ('others', 'NNS'), ('courteous', 'JJ')], [('everyone', 'NN'), ('seat', 'NN'), ('ask', 'VB'), ('neighbor', 'NN'), ('front', 'JJ'), ('back', 'RB'), ('issues', 'NNS'), ('come', 'VBP'), ('good', 'JJ')]], [[('appeared', 'VBD'), ('new', 'JJ')], [('good', 'JJ'), ('ptv', 'NN'), ('entertainment', 'NN')], [('seats', 'NNS'), ('tight', 'VBD'), ('width', 'JJ'), ('leg', 'NN'), ('room', 'NN')], [('difficult', 'JJ'), ('enterexit', 'JJ'), ('seat', 'NN'), ('front', 'NN'), ('reclined', 'VBD')], [('feet', 'NNS'), ('comfort', 'NN'), ('poor', 'JJ'), ('due', 'JJ'), ('restriction', 'NN'), ('seat', 'NN'), ('equipment', 'NN')]], [[('boeing', 'VBG'), ('737800', 'CD'), ('seats', 'NNS'), ('athens', 'VBP'), ('moscow', 'CD'), ('small', 'JJ')], [('table', 'JJ'), ('tray', 'NN'), ('come', 'VBN'), ('fully', 'RB'), ('without', 'IN'), ('stopping', 'VBG'), ('knees', 'NNS'), ('34', 'CD'), ('cm', 'NN'), ('coming', 'VBG'), ('horizontal', 'JJ'), ('position', 'NN'), ('space', 'NN'), ('knees', 'NNS')], [('problems', 'NNS'), ('aeroflot', 'VBP'), ('a320a321', 'JJ'), ('type', 'NN'), ('planes', 'NNS'), ('fly', 'VBP'), ('new', 'JJ'), ('boeing', 'VBG'), ('737800', 'CD'), ('plus', 'JJ'), ('side', 'NN'), ('boeing', 'VBG'), ('737800', 'CD'), ('international', 'JJ'), ('power', 'NN'), ('plugs', 'NNS'), ('2', 'CD'), ('per', 'IN'), ('3', 'CD'), ('seats', 'NNS'), ('charge', 'VBP'), ('laptop', 'JJ'), ('phone', 'NN'), ('flight', 'NN'), ('makes', 'VBZ'), ('arrive', 'JJ'), ('always', 'RB'), ('charged', 'VBN')]], [[('almost', 'RB'), ('wide', 'JJ'), ('seat', 'NN'), ('business', 'NN'), ('class', 'NN'), ('without', 'IN'), ('ability', 'NN'), ('level', 'NN'), ('recline', 'NN')], [('really', 'RB'), ('comfortable', 'JJ'), ('day', 'NN'), ('time', 'NN'), ('seat', 'NN'), ('better', 'RBR'), ('regular', 'JJ'), ('economy', 'NN'), ('seating', 'VBG'), ('sleep', 'JJ')], [('really', 'RB'), ('impressed', 'JJ'), ('value', 'NN')], [('seat', 'NN'), ('coat', 'NN'), ('hook', 'NN'), ('usb', 'JJ'), ('ac', 'JJ'), ('power', 'NN'), ('ports', 'NNS'), ('10', 'CD'), ('inch', 'NN'), ('entertainment', 'NN'), ('system', 'NN')], [('double', 'JJ'), ('armrests', 'NNS'), ('extra', 'JJ'), ('storage', 'NN'), ('spaces', 'NNS'), ('water', 'NN'), ('bottles', 'NNS'), ('items', 'NNS')]], [[('differences', 'NNS'), ('aircraft', 'VBP'), ('model', 'NN'), ('a330300', 'NN'), ('case', 'NN')], [('longhaul', 'NN'), ('seats', 'NNS'), ('good', 'JJ'), ('short', 'JJ'), ('–haul', 'NN'), ('4', 'CD'), ('h', 'NN'), ('little', 'JJ'), ('bit', 'NN'), ('crowded', 'VBD')], [('entertainment', 'NN'), ('system', 'NN'), ('work', 'NN'), ('smoothly', 'RB')]], [[('easy', 'JJ'), ('space', 'NN'), ('economy', 'NN'), ('passenger', 'NN'), ('front', 'NN'), ('still', 'RB'), ('pushing', 'VBG'), ('pushing', 'VBG'), ('knowing', 'VBG'), ('able', 'JJ'), ('recline', 'JJ'), ('seat', 'NN'), ('becomes', 'NNS'), ('total', 'JJ'), ('joke', 'NN')], [('expect', 'VB'), ('bit', 'NN'), ('better', 'JJ'), ('seat', 'NN'), ('least', 'JJS'), ('personal', 'JJ'), ('screen', 'NN')]], [[('find', 'VB'), ('seats', 'NNS'), ('a332', 'VBP'), ('comfortable', 'JJ'), ('aeroflots', 'NNS'), ('a319320', 'VBP'), ('fleet', 'NN')], [('recline', 'JJ'), ('seat', 'NN'), ('bottom', 'JJ'), ('part', 'NN'), ('moves', 'VBZ'), ('forward', 'RB'), ('whereby', 'JJ'), ('average', 'JJ'), ('legroom', 'NN'), ('becomes', 'VBZ'), ('even', 'RB'), ('smaller', 'JJR')] ...

# %% [markdown]
# ### # Bag of words
# * feature vector containing all the words in text
#
# ### # Dependency Parse Trees
# * Sectences are structured by identifying the grammatical relationship among words to from shorter sentences
# * Phrase extraction at min level
#
# ### # Part-of-Speech Tagging
# * Each word in bag of word is assigned to respective POS.
# * Used to identify verb, adjective in case of _"sentiment mining"_ .
#
# ### # Named Entity Recognition
# * Identify noun  from text and Classify them.
#
# ### # Negation Identification
# * Detecting sarcasm and flaging them.
#
# ### # Collocation (n-gram feature)
# * Identifying relationship between words
# * Extract feature by grouping.
#
# ### # Word  Sense Disambiguation
# * Identify right sense of word _(same word may be used as noun and verb with completly dif. meaning)_
#
# <br>
#
# ### # Lexical Normalization (Noice Removal)
# * Stemming (removes suffixes) (Faster)
# * Lemmatization (converting to thier grammertical root) (Better)
#
#
# ### # Word Standardization (Noice Removal) _[Not included in example]_
# * Extract meaning from text, convert shorthand,ackronyms and bad formating to real words
# * Spell Check

# %%
from nltk.corpus import wordnet as wn

# %%
def get_wordnet_pos(nltk_tag):

    if nltk_tag.startswith('J'):
        return wn.ADJ
    elif nltk_tag.startswith('V'):
        return wn.VERB
    elif nltk_tag.startswith('R'):
        return wn.ADV
    else:
        return wn.NOUN

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import sentiwordnet as swn

# %%
lemmatizer = WordNetLemmatizer()
length = len(pos_tag_list) # == X_reviews.size

# %%
sentiment_list=[];

# %%
for idx in range(0,length):
    sentiment = 0.0;   #find sentiment of whole review
    for sentence in pos_tag_list[idx]:
        for word,tag in sentence:
            lemma = lemmatizer.lemmatize(word,get_wordnet_pos(tag))
            if not lemma:
                continue
            
            synset = wn.synsets(lemma,get_wordnet_pos(tag))
            if not synset:
                continue
            
            swn_synset = swn.senti_synset(synset[0].name())
            sentiment += swn_synset.pos_score() - swn_synset.neg_score()
            
    sentiment_list.append(sentiment)

# %%
sentiment_list
# Out:
# [1.5,
#  0.0,
#  2.375,
#  -0.625,
#  -1.125,
#  1.0,
#  -0.25,
#  1.375,
#  -0.5,
#  0.625,
#  2.75,
#  1.75,
#  -1.125,
#  3.0,
#  -0.5,
#  -2.25,
#  0.75,
#  0.0,
#  0.875,
#  1.5,
#  -0.75,
#  0.75,
#  1.5,
#  0.5,
#  1.0,
#  -0.125,
#  0.625,
#  2.75,
#  -0.125,
#  2.375,
#  -1.375,
#  -0.625,
#  -2.375,
#  2.5,
#  0.875,
#  1.125,
#  1.5,
#  -0.625,
#  -0.25,
#  -0.75,
#  -0.75,
#  -1.375,
#  0.375,
#  -1.625,
#  0.375,
#  1.0,
#  2.0,
#  0.0,
#  1.375,
#  0.5,
#  6.625,
#  1.75,
#  -1.75,
#  -2.375,
#  -2.125,
#  -3.0,
#  0.25,
#  -2.375,
#  -0.75,
#  2.5,
#  0.125,
#  -1.625,
#  0.0,
#  -1.25,
#  -2.125,
#  0.375,
#  -1.625,
#  -0.375,
#  -1.875,
#  0.0,
#  -1.625,
#  0.125,
#  2.125,
#  -1.125,
#  -3.125,
#  0.0,
#  0.875,
#  -2.0,
#  0.75,
#  1.75,
#  -3.125,
#  -6.375,
#  -2.125,
#  2.625,
#  -2.0,
#  0.625,
#  0.0,
#  -0.5,
#  0.0,
#  -1.125,
#  -3.125,
#  -0.25,
#  1.25,
#  0.125,
#  -4.181,
#  0.0,
#  -0.25,
#  -0.375,
#  -1.125,
#  -0.875,
#  -3.5,
#  1.25,
#  -1.125,
#  -2.625,
#  4.25,
#  2.375,
#  -0.375,
#  -1.125,
#  -2.0,
#  -1.0,
#  -4.125,
#  -2.5,
#  1.0,
#  0.75,
#  -1.125,
#  -0.125,
#  0.125,
#  -1.25,
#  -4.625,
#  0.5,
#  0.625,
#  0.375,
#  0.0,
#  -3.125,
#  1.513,
#  -3.25,
#  -1.75,
#  -0.875,
#  -3.0,
#  -1.0,
#  1.875,
#  -0.625,
#  -1.375,
#  0.75,
#  -1.0,
#  -1.625,
#  -2.25,
#  -1.75,
#  2.125,
#  -3.0,
#  2.0,
#  0.5,
#  -3.375,
#  -2.375,
#  -1.625,
#  1.875,
#  1.375,
#  1.875,
#  -2.25,
#  -3.5,
#  -0.625,
#  0.5,
#  -1.375,
#  2.125,
#  2.375,
#  -1.25,
#  0.875,
#  -0.375,
#  1.25,
#  2.375,
#  -1.375,
#  -2.25,
#  -0.75,
#  -2.75,
#  0.875,
#  -0.25,
#  0.125,
#  1.375,
#  -1.25,
#  1.25,
#  -1.375,
#  1.875,
#  0.75,
#  1.5,
#  -0.5,
#  -1.25,
#  -0.375,
#  0.75,
#  -2.25,
#  -1.0,
#  -1.625,
#  -2.625,
#  0.0,
#  -1.875,
#  0.25,
#  -1.5,
#  -2.125,
#  -0.125,
#  -1.125,
#  0.375,
#  -1.0,
#  -1.0,
#  -1.25,
#  -2.125,
#  -1.5,
#  -1.75,
#  1.0,
#  -0.75,
#  -3.0,
#  -0.25,
#  -0.75,
#  -1.125,
#  7.25,
#  0.5,
#  0.25,
#  -0.375,
#  1.0,
#  -1.125,
#  0.625,
#  1.25,
#  1.625,
#  -1.25,
#  0.625,
#  -2.125,
#  0.875,
#  1.125,
#  -0.625,
#  -1.5,
#  -1.125,
#  -0.625,
#  -2.75,
#  1.875,
#  -1.75,
#  0.625,
#  -2.0,
#  -0.125,
#  0.75,
#  -0.375,
#  -1.0,
#  0.25,
#  -0.5,
#  2.5,
#  1.625,
#  0.125,
#  0.0,
#  0.375,
#  -2.5,
#  -0.75,
#  -0.75,
#  0.375,
#  -0.875,
#  -0.375,
#  1.0,
#  0.625,
#  2.75,
#  0.0,
#  -0.75,
#  -1.0,
#  1.75,
#  -0.375,
#  -0.5,
#  -0.625,
#  0.25,
#  -0.625,
#  -2.0,
#  -1.5,
#  -1.75,
#  0.0,
#  -0.75,
#  -2.25,
#  -1.125,
#  0.125,
#  1.375,
#  -0.25,
#  2.125,
#  1.0,
#  1.612,
#  -1.25,
#  2.875,
#  -1.5,
#  1.75,
#  -1.625,
#  2.25,
#  -0.375,
#  -2.375,
#  -0.875,
#  1.375,
#  0.375,
#  -0.125,
#  -3.875,
#  0.125,
#  -2.875,
#  -2.125,
#  1.0,
#  -2.25,
#  -1.75,
#  0.375,
#  1.375,
#  -1.0,
#  0.25,
#  4.0,
#  -1.0,
#  0.75,
#  6.625,
#  -1.125,
#  -0.375,
#  1.125,
#  -2.25,
#  -0.125,
#  1.0,
#  -2.75,
#  -0.625,
#  0.625,
#  -1.5,
#  2.75,
#  3.75,
#  -2.125,
#  1.75,
#  1.875,
#  -1.625,
#  0.0,
#  0.0,
#  0.75,
#  -0.5,
#  0.125,
#  -1.375,
#  -1.375,
#  0.75,
#  -0.25,
#  -1.75,
#  -0.5,
#  -0.375,
#  -1.0,
#  2.25,
#  -1.0,
#  0.5,
#  -2.75,
#  -0.25,
#  0.75,
#  1.75,
#  -4.5,
#  0.0,
#  1.125,
#  -1.875,
#  6.125,
#  1.5,
#  1.25,
#  1.125,
#  1.875,
#  -0.75,
#  2.75,
#  -1.0,
#  0.875,
#  0.75,
#  0.875,
#  -1.125,
#  2.25,
#  0.0,
#  -2.125,
#  -0.25,
#  1.625,
#  -0.5,
#  -3.25,
#  -0.5,
#  2.75,
#  1.0,
#  5.25,
#  2.375,
#  0.5,
#  1.25,
#  -1.375,
#  -2.625,
#  -3.875,
#  1.125,
#  -0.25,
#  -0.25,
#  -0.875,
#  -2.0,
#  -3.75,
#  1.25,
#  -5.375,
#  -2.125,
#  0.75,
#  2.25,
#  1.75,
#  0.75,
#  -1.875,
#  -1.125,
#  2.125,
#  -1.0,
#  1.75,
#  0.75,
#  -1.75,
#  -1.625,
#  1.125,
#  -0.875,
#  3.0,
#  -1.0,
#  -0.125,
#  -0.375,
#  0.0,
#  1.25,
#  -0.875,
#  1.5,
#  -0.75,
#  1.625,
#  -0.5,
#  -1.0,
#  -0.875,
#  0.875,
#  -2.25,
#  -0.125,
#  -1.5,
#  -2.625,
#  0.25,
#  -0.125,
#  -2.625,
#  -0.125,
#  -0.625,
#  -0.125,
#  -0.5,
#  -0.75,
#  -1.0,
#  -0.25,
#  -0.375,
#  1.125,
#  -1.25,
#  1.5,
#  -3.375,
#  -0.375,
#  -2.625,
#  -1.5,
#  -1.875,
#  -1.5,
#  -0.375,
#  -0.125,
#  0.625,
#  0.625,
#  1.875,
#  1.125,
#  0.25,
#  1.375,
#  -0.125,
#  0.125,
#  0.25,
#  -2.5,
#  0.0,
#  1.125,
#  1.5,
#  1.0,
#  -0.375,
#  1.5,
#  0.0,
#  -1.5,
#  0.75,
#  -0.625,
#  0.625,
#  -1.0,
#  -1.875,
#  1.5,
#  1.875,
#  0.125,
#  -2.25,
#  -0.25,
#  -1.0,
#  1.75,
#  -1.0,
#  -0.125,
#  0.75,
#  0.0,
#  -0.875,
#  2.0,
#  0.625,
#  2.0,
#  -0.75,
#  -2.375,
#  1.75,
#  -0.75,
#  0.375,
#  -0.5,
#  -2.125,
#  0.5,
#  -1.125,
#  -2.125,
#  -0.875,
#  0.125,
#  -1.25,
#  0.25,
#  1.0,
#  1.0,
#  -3.75,
#  -0.75,
#  -1.375,
#  2.0,
#  -0.875,
#  0.125,
#  0.625,
#  2.25,
#  -0.5,
#  -0.75,
#  0.0,
#  -0.625,
#  1.5,
#  -1.0,
#  -0.25,
#  1.5,
#  -1.375,
#  0.875,
#  -1.25,
#  -0.75,
#  1.0,
#  -0.25,
#  -2.5,
#  0.125,
#  0.0,
#  1.75,
#  -1.75,
#  -0.375,
#  -1.0,
#  -0.375,
#  2.0,
#  1.25,
#  -1.625,
#  0.0,
#  3.0,
#  -1.875,
#  -5.375,
#  0.25,
#  -2.5,
#  -2.875,
#  1.0,
#  -1.375,
#  -0.625,
#  -3.25,
#  -0.75,
#  1.625,
#  -0.375,
#  -0.375,
#  -2.0,
#  -2.0,
#  0.25,
#  -2.125,
#  -1.125,
#  1.0,
#  -2.25,
#  -0.625,
#  -1.125,
#  -0.625,
#  0.75,
#  -2.625,
#  -2.5,
#  -2.0,
#  -0.75,
#  -1.25,
#  -0.375,
#  -0.875,
#  -0.625,
#  -1.5,
#  1.5,
#  -1.0,
#  -0.25,
#  -0.25,
#  -0.875,
#  0.125,
#  1.375,
#  2.75,
#  1.75,
#  0.75,
#  -0.25,
#  -4.875,
#  -3.625,
#  -0.75,
#  -3.875,
#  0.625,
#  -0.5,
#  -1.875,
#  -0.125,
#  -3.25,
#  1.5,
#  0.625,
#  0.25,
#  -2.25,
#  -1.125,
#  0.0,
#  -0.75,
#  -0.25,
#  1.375,
#  2.25,
#  -1.125,
#  -0.375,
#  1.125,
#  -0.125,
#  -1.125,
#  -0.125,
#  -0.75,
#  -1.375,
#  -1.875,
#  -0.75,
#  1.125,
#  -0.75,
#  0.125,
#  1.0,
#  -0.875,
#  -0.375,
#  -1.25,
#  0.875,
#  0.25,
#  2.5,
#  -0.375,
#  -0.25,
#  -0.25,
#  -0.25,
#  2.75,
#  0.5,
#  -1.5,
#  -1.0,
#  -1.875,
#  0.25,
#  -3.0,
#  0.5,
#  1.125,
#  -1.125,
#  -1.0,
#  -1.625,
#  -1.0,
#  -1.125,
#  -2.0,
#  0.25,
#  1.25,
#  1.875,
#  -0.875,
#  0.375,
#  0.0,
#  1.75,
#  -0.75,
#  -0.25,
#  0.625,
#  -0.375,
#  1.125,
#  0.5,
#  0.75,
#  2.5,
#  -0.875,
#  -4.875,
#  -0.625,
#  1.625,
#  -0.5,
#  -0.5,
#  -2.0,
#  -0.625,
#  -0.625,
#  -1.875,
#  -0.125,
#  0.625,
#  -1.625,
#  1.0,
#  -2.0,
#  -0.25,
#  -1.5,
#  -1.5,
#  -3.5,
#  -2.125,
#  0.0,
#  0.625,
#  -0.5,
#  0.25,
#  -0.625,
#  0.875,
#  2.25,
#  0.625,
#  0.125,
#  -0.125,
#  -1.5,
#  -2.875,
#  -2.875,
#  1.25,
#  -1.25,
#  0.375,
#  -3.125,
#  0.5,
#  0.0,
#  -0.125,
#  -1.375,
#  -4.25,
#  -1.25,
#  -0.25,
#  -0.875,
#  0.75,
#  -0.25,
#  0.25,
#  -3.25,
#  2.0,
#  1.0,
#  0.5,
#  1.25,
#  -2.125,
#  -0.5,
#  -0.375,
#  -2.0,
#  -4.25,
#  2.25,
#  -2.25,
#  1.0,
#  -1.375,
#  -2.875,
#  -1.5,
#  -0.5,
#  0.375,
#  -0.625,
#  -0.125,
#  0.25,
#  -2.625,
#  -2.125,
#  -0.625,
#  -1.75,
#  -0.625,
#  0.875,
#  -0.375,
#  -0.125,
#  -1.25,
#  -3.375,
#  -1.125,
#  1.25,
#  1.875,
#  -0.25,
#  0.375,
#  1.875,
#  0.5,
#  0.125,
#  -0.875,
#  1.5,
#  -0.25,
#  -1.125,
#  -0.75,
#  -0.5,
#  -0.125,
#  -1.125,
#  -2.25,
#  0.0,
#  -1.625,
#  0.625,
#  1.5,
#  -0.25,
#  0.25,
#  -1.5,
#  -3.125,
#  1.125,
#  0.0,
#  0.625,
#  1.25,
#  1.75,
#  5.25,
#  1.25,
#  2.5,
#  0.75,
#  -1.875,
#  -1.875,
#  -2.125,
#  0.875,
#  1.75,
#  -2.0,
#  1.25,
#  -0.25,
#  1.25,
#  -3.625,
#  -1.0,
#  3.625,
#  1.5,
#  0.375,
#  0.125,
#  -2.625,
#  -3.125,
#  -0.125,
#  1.5,
#  -0.5,
#  3.875,
#  -3.625,
#  -1.125,
#  1.625,
#  1.875,
#  -1.0,
#  2.625,
#  0.625,
#  -1.125,
#  -1.875,
#  -1.375,
#  3.0,
#  -0.625,
#  0.375,
#  0.0,
#  2.0,
#  1.5,
#  -2.875,
#  2.0,
#  3.5,
#  4.625,
#  -2.25,
#  1.375,
#  2.25,
#  1.0,
#  -1.25,
#  0.75,
#  -1.25,
#  -0.875,
#  0.875,
#  -2.75,
#  -0.875,
#  -1.5,
#  -0.375,
#  -1.5,
#  -1.375,
#  0.25,
#  1.375,
#  0.25,
#  -0.75,
#  -0.375,
#  -1.125,
#  -1.0,
#  -2.25,
#  -0.375,
#  -0.25,
#  -0.25,
#  -1.875,
#  1.375,
#  -0.375,
#  -2.0,
#  0.0,
#  1.25,
#  0.625,
#  -2.375,
#  -1.25,
#  -0.875,
#  1.375,
#  -1.625,
#  -1.625,
#  1.375,
#  1.875,
#  0.5,
#  0.625,
#  0.0,
#  -1.375,
#  -1.25,
#  -0.5,
#  0.625,
#  -0.5,
#  -1.25,
#  -0.75,
#  -1.209,
#  -1.125,
#  3.875,
#  0.5,
#  0.625,
#  0.625,
#  2.0,
#  0.5,
#  -2.125,
#  -2.0,
#  0.0,
#  4.5,
#  2.625,
#  1.0,
#  -0.25,
#  3.125,
#  4.0,
#  0.125,
#  -0.5,
#  0.25,
#  -0.75,
#  0.75,
#  1.625,
#  -3.25,
#  2.875,
#  -0.875,
#  -0.875,
#  -1.5,
#  -0.5,
#  3.25,
#  -1.125,
#  -0.125,
#  0.125,
#  -1.375,
#  0.25,
#  2.25,
#  -3.875,
#  -1.625,
#  -0.75,
#  0.0,
#  -0.375,
#  1.75,
#  -0.125,
#  1.0,
#  4.125,
#  0.625,
#  -1.375,
#  -0.125,
#  -4.0,
#  0.625,
#  0.125,
#  0.0,
#  1.75,
#  4.125,
#  1.5,
#  -2.5,
#  2.125,
#  -1.125,
#  -0.75,
#  2.875,
#  0.125,
#  -0.875,
#  -1.25,
#  -0.75,
#  0.75,
#  1.5,
#  -1.25,
#  -2.5,
#  1.125,
#  -1.875,
#  -0.25,
#  -1.125,
#  2.375,
#  0.375,
#  1.25,
#  0.375,
#  1.625,
#  0.0,
#  1.5,
#  -1.125,
#  0.375,
#  2.0,
#  2.0,
#  -0.25,
#  -0.625,
#  -2.125,
#  -0.375,
#  -0.125,
#  -1.125,
#  1.75,
#  0.375,
#  1.0,
#  -0.375,
#  1.625,
#  1.125,
#  -2.25,
#  3.625,
#  -0.25,
#  -0.125,
#  3.375,
#  -0.625,
#  0.75,
#  0.125,
#  4.75,
#  -0.875,
#  6.5,
#  0.5,
#  0.875,
#  0.0,
#  0.125,
#  -1.125,
#  -0.75,
#  0.0,
#  2.0,
#  0.75,
#  -1.25,
#  0.625,
#  -0.375,
#  1.75,
#  0.0,
#  0.375,
#  -1.25,
#  1.0,
#  0.875,
#  0.25,
#  -0.5,
#  -0.625,
#  2.75,
#  -0.75,
#  1.625,
#  -2.75,
#  1.125,
#  -0.625,
#  -0.5,
#  -0.375,
#  0.625,
#  1.5,
#  0.5,
#  1.125,
#  0.125,
#  0.75,
#  -1.5,
#  1.75,
#  0.5,
#  3.75,
#  1.625,
#  0.875,
#  2.0,
#  0.625,
#  0.5,
#  0.625,
#  0.25,
#  -1.0,
#  -1.625,
#  1.0,
#  1.25,
#  1.625,
#  -1.25,
#  0.25,
#  -0.75,
#  -2.875,
#  -1.75,
#  -0.625,
#  ...]

# %% [markdown]
# ### but what is the threshold for recommendation?

# %%
def predict(sentiment_list,threshold):
    y = [];
    for idx in range (0,len(sentiment_list)):
        if sentiment_list[idx] <= threshold:
            y.append(0)
        elif sentiment_list[idx] > threshold:
            y.append(1)
    return y;

# %%
def accuracy(sentiment_list,threshold): # same as sklearn.metric.accuracy
    return np.round((sum(np.where((predict(sentiment_list,threshold)==y), 1, 0))/X_reviews.size),4)

# %%
X_thresholds = np.round(np.linspace(-2 ,2,40),2)

# %%
Y_scores = [accuracy(sentiment_list,x) for x in X_thresholds]

# %%
plt.scatter(X_thresholds,Y_scores)

# %%
threshold = X_thresholds[Y_scores.index(max(Y_scores))]
threshold
# Out:
# 0.77

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
y_predict = predict(sentiment_list,threshold)

# %%
print("accuracy score: {0:.4f}\n".format(accuracy_score(y, y_predict)))
print("Classification Report: \n {}\n".format(classification_report(y, y_predict)))
print("Confusion Matrix: \n {}\n".format(confusion_matrix(y, y_predict)))
# Out:
# accuracy score: 0.7083
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.86      0.79       800
#            1       0.64      0.45      0.53       458
#
#    micro avg       0.71      0.71      0.71      1258
#    macro avg       0.69      0.65      0.66      1258
# weighted avg       0.70      0.71      0.69      1258
#
#
# Confusion Matrix:
#  [[687 113]
#  [254 204]]

# %% [markdown]
# ***
#
#
# <center><i><h1> Supervised </h1></i></center>
#
#
#
# <br>
# <br>
# <br>
#
# ## # Tf-Idf (Feature Extraction)
# * Term frequency-inverse document frequency
# * Used instead of word Count

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df[['review']],df['recommended'],test_size=0.3)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vector = CountVectorizer()

X_train_vect = count_vector.fit_transform(X_train['review'])
X_test_vect = count_vector.transform(X_test['review'])

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_Transformer = TfidfTransformer()

X_train_tfidf = tfidf_Transformer.fit_transform(X_train_vect)
X_test_tfidf = tfidf_Transformer.transform(X_test_vect)

# %% [markdown]
# <br>
#
# # Naive Bayes:

# %%
X_test_tfidf
# Out:
# <378x5241 sparse matrix of type '<class 'numpy.float64'>'
# 	with 12665 stored elements in Compressed Sparse Row format>
